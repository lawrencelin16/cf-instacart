# %% [markdown]
# # List of contents
# ### 01. Importing libraries and data
# ### 02. Grouping and aggregating
# ### 03. Creating flag columns with aggregated variables
# ### 04. Clean and export data

# %% [markdown]
# # 01. Importing libraries and data

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import data
path = r'C:\Users\Lawrence\Documents\Career Foundry Projects\Data Immersion\Achievement #4\2023 Instacart Basket Analysis'
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_derived.pkl'))

# %% [markdown]
# # 02. Grouping and aggregating

# %%
# Step 2
# Find the aggregated mean of the order_number column grouped by department_id
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %%
# Step 3 
# Compare these results to the subset of 1,000,000 orders
subset = ords_prods_merge[:1000000]
subset.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %% [markdown]
# The results for the full dataframe contain information about orders from all 22 departments, while the results for the subset contain information about orders from only 8 departments. The means are also different. The means for the full dataframe are smaller for most department IDs (4, 7, 13, 14, 16, and 19), but larger for a few (17 and 20).

# %% [markdown]
# # 03. Creating flag columns with aggregated variables

# %%
# Step 4
# Create a loyalty flag column for existing customers
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\Lawrence\AppData\Local\Temp\ipykernel_23532\2136683801.py:3: FutureWarning: The provided callable <function amax at 0x00000222748198A0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(30)
# Out:
#     order_id  user_id  order_number  orders_day_of_the_week  \
# 0    2539329        1             1                       2
# 1    2398795        1             2                       3
# 2     473747        1             3                       3
# 3    2254736        1             4                       4
# 4     431534        1             5                       4
# 5    3367565        1             6                       2
# 6     550135        1             7                       1
# 7    3108588        1             8                       1
# 8    2295261        1             9                       1
# 9    2550362        1            10                       4
# 10   2968173       15            15                       1
# 11   1870022       15            17                       2
# 12   1911383       15            18                       2
# 13   2715276       15            21                       1
# 14    487368       15            22                       1
# 15   2293453       19             2                       5
# 16   1973799       19             5                       6
# 17    532817       19             7                       4
# 18   1573906       21            10                       3
# 19   1593000       31            10                       3
# 20   2231262       31            17                       3
# 21   2580647       43             6                       4
# 22   2187180       43             9                       4
# 23   2497897       52             1                       1
# 24   1318871       52             2                       1
# 25   1261384       52             3                       1
# 26    580568       52             5                       2
# 27   2428073       52             7                       2
# 28    342306       52             9                       1
# 29   1520353       52            10                       2
#
#     order_hour_of_day  days_since_prior_order_number  product_id  \
# 0                   8                            NaN         196
# 1                   7                           15.0         196
# 2                  12                           21.0         196
# 3                   7                           29.0         196
# 4                  15                           28.0         196
# 5                   7                           19.0         196
# 6                   9                           20.0         196
# 7                  14                           14.0         196
# 8                  16                            0.0         196
# 9                   8                           30.0         196
# 10                  9                            7.0         196
# 11                 16                            8.0         196
# 12                 11                            7.0         196
# 13                  9                            7.0         196
# 14                 10                           14.0         196
# 15                 14                            6.0         196
# 16                 12                            8.0         196
# 17                 17                            6.0         196
# 18                 10                            6.0         196
# 19                  8                            7.0         196
# 20                 11                            8.0         196
# 21                 16                            4.0         196
# 22                 12                            3.0         196
# 23                  9                            NaN         196
# 24                 10                            7.0         196
# 25                 10                            7.0         196
# 26                 10                            8.0         196
# 27                  7                            8.0         196
# 28                 11                            7.0         196
# 29                 10                            8.0         196
#
#     add_to_cart_order  reordered product_name  aisle_id  department_id  \
# 0                   1          0         Soda        77              7
# 1                   1          1         Soda        77              7
# 2                   1          1         Soda        77              7
# 3                   1          1         Soda        77              7
# 4                   1          1         Soda        77              7
# 5                   1          1         Soda        77              7
# 6                   1          1         Soda        77              7
# 7                   2          1         Soda        77              7
# 8                   4          1         Soda        77              7
# 9                   1          1         Soda        77              7
# 10                  2          0         Soda        77              7
# 11                  6          1         Soda        77              7
# 12                  1          1         Soda        77              7
# 13                  1          1         Soda        77              7
# 14                  1          1         Soda        77              7
# 15                  3          0         Soda        77              7
# 16                 15          1         Soda        77              7
# 17                  1          1         Soda        77              7
# 18                  2          0         Soda        77              7
# 19                 17          0         Soda        77              7
# 20                 14          1         Soda        77              7
# 21                  9          0         Soda        77              7
# 22                  1          1         Soda        77              7
# 23                  4          0         Soda        77              7
# 24                  5          1         Soda        77              7
# 25                  3          1         Soda        77              7
# 26                  6          1         Soda        77              7
# 27                  5          1         Soda        77              7
# 28                  5          1         Soda        77              7
# 29                  4          1         Soda        77              7
#
#     prices _merge    price_range_loc     busiest_day    busiest_days  \
# 0      9.0   both  Mid-range product  Regularly busy  Regularly busy
# 1      9.0   both  Mid-range product  Regularly busy    Slowest days
# 2      9.0   both  Mid-range product  Regularly busy    Slowest days
# 3      9.0   both  Mid-range product      Least busy    Slowest days
# 4      9.0   both  Mid-range product      Least busy    Slowest days
# 5      9.0   both  Mid-range product  Regularly busy  Regularly busy
# 6      9.0   both  Mid-range product  Regularly busy    Busiest days
# 7      9.0   both  Mid-range product  Regularly busy    Busiest days
# 8      9.0   both  Mid-range product  Regularly busy    Busiest days
# 9      9.0   both  Mid-range product      Least busy    Slowest days
# 10     9.0   both  Mid-range product  Regularly busy    Busiest days
# 11     9.0   both  Mid-range product  Regularly busy  Regularly busy
# 12     9.0   both  Mid-range product  Regularly busy  Regularly busy
# 13     9.0   both  Mid-range product  Regularly busy    Busiest days
# 14     9.0   both  Mid-range product  Regularly busy    Busiest days
# 15     9.0   both  Mid-range product  Regularly busy  Regularly busy
# 16     9.0   both  Mid-range product  Regularly busy  Regularly busy
# 17     9.0   both  Mid-range product      Least busy    Slowest days
# 18     9.0   both  Mid-range product  Regularly busy    Slowest days
# 19     9.0   both  Mid-range product  Regularly busy    Slowest days
# 20     9.0   both  Mid-range product  Regularly busy    Slowest days
# 21     9.0   both  Mid-range product      Least busy    Slowest days
# 22     9.0   both  Mid-range product      Least busy    Slowest days
# 23     9.0   both  Mid-range product  Regularly busy    Busiest days
# 24     9.0   both  Mid-range product  Regularly busy    Busiest days
# 25     9.0   both  Mid-range product  Regularly busy    Busiest days
# 26     9.0   both  Mid-range product  Regularly busy  Regularly busy
# 27     9.0   both  Mid-range product  Regularly busy  Regularly busy
# 28     9.0   both  Mid-range product  Regularly busy    Busiest days
# 29     9.0   both  Mid-range product  Regularly busy  Regularly busy
#
#    busiest_period_of_day  max_order
# 0         Average orders         10
# 1         Average orders         10
# 2            Most orders         10
# 3         Average orders         10
# 4            Most orders         10
# 5         Average orders         10
# 6            Most orders         10
# 7            Most orders         10
# 8            Most orders         10
# 9         Average orders         10
# 10           Most orders         22
# 11           Most orders         22
# 12           Most orders         22
# 13           Most orders         22
# 14           Most orders         22
# 15           Most orders          9
# 16           Most orders          9
# 17        Average orders          9
# 18           Most orders         33
# 19        Average orders         20
# 20           Most orders         20
# 21           Most orders         11
# 22           Most orders         11
# 23           Most orders         27
# 24           Most orders         27
# 25           Most orders         27
# 26           Most orders         27
# 27        Average orders         27
# 28           Most orders         27
# 29           Most orders         27

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
# Out:
# C:\Users\Lawrence\AppData\Local\Temp\ipykernel_23532\3647449420.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Loyal customer' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] > 10)
                     & (ords_prods_merge['max_order'] <= 40), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# Step 5
# Check basic statistics of the product prices for each loyalty category
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %%
# Step 6
# Create a spending flag for each user based on the average price across all their orders
ords_prods_merge['avg_price_of_user'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\Lawrence\AppData\Local\Temp\ipykernel_23532\3696022780.py:3: FutureWarning: The provided callable <function mean at 0x000002227481A5C0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['avg_price_of_user'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge['avg_price_of_user'].head(10)
# Out:
# 0    6.367797
# 1    6.367797
# 2    6.367797
# 3    6.367797
# 4    6.367797
# 5    6.367797
# 6    6.367797
# 7    6.367797
# 8    6.367797
# 9    6.367797
# Name: avg_price_of_user, dtype: float64

# %%
ords_prods_merge.loc[ords_prods_merge['avg_price_of_user'] < 10, 'spending_level'] = 'Low spender.'
# Out:
# C:\Users\Lawrence\AppData\Local\Temp\ipykernel_23532\3880967531.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Low spender.' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_merge.loc[ords_prods_merge['avg_price_of_user'] < 10, 'spending_level'] = 'Low spender.'

# %%
ords_prods_merge.loc[ords_prods_merge['avg_price_of_user'] >= 10, 'spending_level'] = 'High spender.'

# %%
ords_prods_merge['spending_level'].value_counts(dropna = False)
# Out:
# spending_level
# Low spender.     31770614
# High spender.      634245
# Name: count, dtype: int64

# %%
# Step 7
# Create an order frequency flag that marks the regularity of a user's ordering behavior
# according to the median in the "days_since_prior_order" column
ords_prods_merge['median_days_since_prior_order'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order_number'].transform(np.median)
# Out:
# C:\Users\Lawrence\AppData\Local\Temp\ipykernel_23532\3020658915.py:4: FutureWarning: The provided callable <function median at 0x000002227495BEC0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['median_days_since_prior_order'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order_number'].transform(np.median)

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] > 20, 'ordering_regularity'] = 'Non-frequent customer.'
# Out:
# C:\Users\Lawrence\AppData\Local\Temp\ipykernel_23532\680299955.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Non-frequent customer.' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] > 20, 'ordering_regularity'] = 'Non-frequent customer.'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_days_since_prior_order'] <= 20)
                     & (ords_prods_merge['median_days_since_prior_order'] > 10), 'ordering_regularity'] = 'Regular customer.'

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] <= 10, 'ordering_regularity'] = 'Frequent customer.'

# %% [markdown]
# # 04. Clean and export data

# %%
ords_prods_merge['ordering_regularity'].value_counts(dropna = False)
# Out:
# ordering_regularity
# Frequent customer.        21559853
# Regular customer.          7208564
# Non-frequent customer.     3636437
# NaN                              5
# Name: count, dtype: int64

# %%
# Investigate the 5 counts of NaN
ords_prods_merge.loc[ords_prods_merge['ordering_regularity'].isna()]
# Out:
#           order_id  user_id  order_number  orders_day_of_the_week  \
# 13645692    895835   159838             1                       0
# 17251990    895835   159838             1                       0
# 17622767    895835   159838             1                       0
# 24138593    895835   159838             1                       0
# 25880002    895835   159838             1                       0
#
#           order_hour_of_day  days_since_prior_order_number  product_id  \
# 13645692                 17                            NaN       10749
# 17251990                 17                            NaN       33401
# 17622767                 17                            NaN       23695
# 24138593                 17                            NaN       21334
# 25880002                 17                            NaN       22198
#
#           add_to_cart_order  reordered  \
# 13645692                  3          0
# 17251990                  6          0
# 17622767                  2          0
# 24138593                  5          0
# 25880002                  1          0
#
#                                                product_name  ...  \
# 13645692                            Organic Red Bell Pepper  ...
# 17251990                               Goat Cheese Crumbles  ...
# 17622767                           California Veggie Burger  ...
# 24138593                              Organic Peeled Garlic  ...
# 25880002  4X Ultra Concentrated Natural Laundry Detergen...  ...
#
#             price_range_loc  busiest_day  busiest_days busiest_period_of_day  \
# 13645692  Mid-range product  Busiest day  Busiest days        Average orders
# 17251990  Mid-range product  Busiest day  Busiest days        Average orders
# 17622767  Low-range product  Busiest day  Busiest days        Average orders
# 24138593  Mid-range product  Busiest day  Busiest days        Average orders
# 25880002  Low-range product  Busiest day  Busiest days        Average orders
#
#          max_order  loyalty_flag avg_price_of_user spending_level  \
# 13645692         1  New customer              7.42   Low spender.
# 17251990         1  New customer              7.42   Low spender.
# 17622767         1  New customer              7.42   Low spender.
# 24138593         1  New customer              7.42   Low spender.
# 25880002         1  New customer              7.42   Low spender.
#
#           median_days_since_prior_order ordering_regularity
# 13645692                            NaN                 NaN
# 17251990                            NaN                 NaN
# 17622767                            NaN                 NaN
# 24138593                            NaN                 NaN
# 25880002                            NaN                 NaN
#
# [5 rows x 24 columns]

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] == 1].head(30)
# Out:
#           order_id  user_id  order_number  orders_day_of_the_week  \
# 13645692    895835   159838             1                       0
# 17251990    895835   159838             1                       0
# 17622767    895835   159838             1                       0
# 24138593    895835   159838             1                       0
# 25880002    895835   159838             1                       0
#
#           order_hour_of_day  days_since_prior_order_number  product_id  \
# 13645692                 17                            NaN       10749
# 17251990                 17                            NaN       33401
# 17622767                 17                            NaN       23695
# 24138593                 17                            NaN       21334
# 25880002                 17                            NaN       22198
#
#           add_to_cart_order  reordered  \
# 13645692                  3          0
# 17251990                  6          0
# 17622767                  2          0
# 24138593                  5          0
# 25880002                  1          0
#
#                                                product_name  ...  \
# 13645692                            Organic Red Bell Pepper  ...
# 17251990                               Goat Cheese Crumbles  ...
# 17622767                           California Veggie Burger  ...
# 24138593                              Organic Peeled Garlic  ...
# 25880002  4X Ultra Concentrated Natural Laundry Detergen...  ...
#
#             price_range_loc  busiest_day  busiest_days busiest_period_of_day  \
# 13645692  Mid-range product  Busiest day  Busiest days        Average orders
# 17251990  Mid-range product  Busiest day  Busiest days        Average orders
# 17622767  Low-range product  Busiest day  Busiest days        Average orders
# 24138593  Mid-range product  Busiest day  Busiest days        Average orders
# 25880002  Low-range product  Busiest day  Busiest days        Average orders
#
#          max_order  loyalty_flag avg_price_of_user spending_level  \
# 13645692         1  New customer              7.42   Low spender.
# 17251990         1  New customer              7.42   Low spender.
# 17622767         1  New customer              7.42   Low spender.
# 24138593         1  New customer              7.42   Low spender.
# 25880002         1  New customer              7.42   Low spender.
#
#           median_days_since_prior_order ordering_regularity
# 13645692                            NaN                 NaN
# 17251990                            NaN                 NaN
# 17622767                            NaN                 NaN
# 24138593                            NaN                 NaN
# 25880002                            NaN                 NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# Identified 5 counts of customers with one-and-done orders. These cases would have a null value for median_days_since_prior order.

# %%
# Data cleaning imported from Exercise 4.9
# Mark rows with outlier prices as missing
ords_prods_merge.loc[ords_prods_merge['prices'] > 100, 'prices'] = np.nan
ords_prods_merge['prices'].max()
# Out:
# 25.0

# %%
# Export data
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_aggregated.pkl'))
